# %%
print("Day 1 - Environment OK")
# Out:
# Day 1 - Environment OK

# %%
import sys
import platform
print("Python version:", sys.version)
print("Interpreter:" , sys.executable) 
print("Platform:" , platform.platform())
# Out:
# Python version: 3.13.5 (v3.13.5:6cb20a219a8, Jun 11 2025, 12:23:45) [Clang 16.0.0 (clang-1600.0.26.6)]
# Interpreter: /Users/ethankeihan/code_repo/aws-data-engineering-30-days/.venv/bin/python
# Platform: macOS-14.7-arm64-arm-64bit-Mach-O

# %%
import pandas as pd
import boto3
print("Pandas version:", pd.__version__)
print("Boto3 version:", boto3.__version__)
# Out:
# Pandas version: 2.3.3
# Boto3 version: 1.41.5

# %%
s3 = boto3.client('s3')
print("Created S3 Client:", s3)
# Out:
# Created S3 Client: <botocore.client.S3 object at 0x123509160>
